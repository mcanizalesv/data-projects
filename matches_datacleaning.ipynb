# %% [markdown]
# **Records for test matches**

# %%
import pandas as pd
import numpy as np 
import matplotlib as plt

# %%
df_matches = pd.read_csv("matches.csv",  sep=';')

# %%
print("\nInformación del DataFrame:")
df_matches.info()
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  69 non-null     object
#  1   Span    69 non-null     object
#  2   Mat     69 non-null     int64
#  3   Inns    69 non-null     int64
#  4   NO      69 non-null     int64
#  5   Runs    69 non-null     int64
#  6   HS      69 non-null     object
#  7   Ave     69 non-null     int64
#  8   BF      66 non-null     object
#  9   SR      66 non-null     float64
#  10  100     69 non-null     int64
#  11  50      69 non-null     int64
#  12  0       69 non-null     int64
#  13  4s      69 non-null     int64
#  14  6s      69 non-null     int64
# dtypes: float64(1), int64(10), object(4)
# memory usage: 8.2+ KB

# %%
df_matches
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS   Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  9994  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  6215   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  6187   2667
# 3      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  6187   2667
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  6097  1707+
# ..                ...        ...  ...   ...  ..   ...   ...   ...    ...
# 64   KD Walters (AUS)  1965-1981   74   125  14  5357   250  4826  8662+
# 65  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  4825  15525
# 66  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  4822  3118+
# 67    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  4821  3217+
# 68   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  4800  2110+
#
#         SR  100  50   0    4s  6s
# 0   5860.0   29  13   7   626   6
# ...

# %% [markdown]
# **Changing columns names**

# %%
df_matches=df_matches.rename(columns = {'Mat':'Matches','NO': 'Not_Outs', 'HS': 'Highest_Inns_Score','BF':'Balls_Faced', 'SR':'Batting_Strike_Rate'})

# %%
df_matches.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3    AC Voges (AUS)  2015-2016       20    31         7  1485
# 4   RG Pollock (SA)  1963-1970       23    41         4  2256
#
#   Highest_Inns_Score   Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  9994       9800+               5860.0   29  13  7  626
# 1                186  6215        1287               9176.0    4   7  1  141
# 2               269*  6187        2667               5568.0    5   4  2  186
# 3               269*  6187        2667               5568.0    5   4  2  186
# 4                274  6097       1707+               5448.0    7  11  1  246
#
#    6s
# 0   6
# 1  23
# 2   5
# 3   5
# 4  11

# %% [markdown]
# **Checking null values**

# %%
df_matches.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df_matches[df_matches['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 10        ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 61  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score   Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 10                207  5861         NaN                  NaN   15  19  6  258
# 16                220  5668         NaN                  NaN   15  14  1  107
# 61               144*  4879         NaN                  NaN    5   6  3   51
#
#     6s
# 10   2
# 16  11
# 61   0

# %%
df_matches['Balls_Faced']=df_matches['Balls_Faced'].fillna(0)

# %%
df_matches['Batting_Strike_Rate']=df_matches['Batting_Strike_Rate'].fillna(0)

# %%
df_matches[df_matches['Player']== 'ED Weekes (WI)']
# Out:
#             Player       Span  Matches  Inns  Not_Outs  Runs  \
# 10  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#    Highest_Inns_Score   Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 10                207  5861           0                  0.0   15  19  6  258
#
#     6s
# 10   2

# %% [markdown]
# **Drop duplicates**

# %%
df_matches.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Length: 69, dtype: bool

# %%
df_matches[df_matches['Player'].duplicated()==1]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs   Runs  \
# 3       AC Voges (AUS)  2015-2016       20    31         7   1485
# 7    H Sutcliffe (ENG)  1924-1935       54    84         9   4555
# 20  GE Tyldesley (ENG)  1921-1929       14    20         2    990
# 26      AD Nourse (SA)  1935-1951       34    62         7   2960
# 31  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 41      SR Waugh (AUS)  1985-2004      168   260        46  10927
# 60     B Mitchell (SA)  1929-1949       42    80         9   3471
#
#    Highest_Inns_Score   Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                269*  6187        2667               5568.0    5   4   2
# 7                 194  6073       6558+               3459.0   16  23   2
# 20                122  5500        178+               2921.0    3   6   2
# 26                231  5381        108+               6388.0    9  14   3
# ...

# %%
df_matches[df_matches['Player'].isin(['AC Voges (AUS)','H Sutcliffe (ENG)','GE Tyldesley (ENG)','AD Nourse (SA)','R Dravid (ICC/IND)','SR Waugh (AUS)','B Mitchell (SA)'])]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs   Runs  \
# 2       AC Voges (AUS)  2015-2016       20    31         7   1485
# 3       AC Voges (AUS)  2015-2016       20    31         7   1485
# 6    H Sutcliffe (ENG)  1924-1935       54    84         9   4555
# 7    H Sutcliffe (ENG)  1924-1935       54    84         9   4555
# 19  GE Tyldesley (ENG)  1921-1929       14    20         2    990
# 20  GE Tyldesley (ENG)  1921-1929       14    20         2    990
# 25      AD Nourse (SA)  1935-1951       34    62         7   2960
# 26      AD Nourse (SA)  1935-1951       34    62         7   2960
# 30  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 31  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 40      SR Waugh (AUS)  1985-2004      168   260        46  10927
# 41      SR Waugh (AUS)  1985-2004      168   260        46  10927
# 59     B Mitchell (SA)  1929-1949       42    80         9   3471
# ...

# %%
df_matches = df_matches.drop_duplicates()

# %%
df_matches[df_matches['Player'].isin(['AC Voges (AUS)','H Sutcliffe (ENG)','GE Tyldesley (ENG)','AD Nourse (SA)','R Dravid (ICC/IND)','SR Waugh (AUS)','B Mitchell (SA)'])]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs   Runs  \
# 2       AC Voges (AUS)  2015-2016       20    31         7   1485
# 6    H Sutcliffe (ENG)  1924-1935       54    84         9   4555
# 19  GE Tyldesley (ENG)  1921-1929       14    20         2    990
# 25      AD Nourse (SA)  1935-1951       34    62         7   2960
# 30  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 40      SR Waugh (AUS)  1985-2004      168   260        46  10927
# 59     B Mitchell (SA)  1929-1949       42    80         9   3471
#
#    Highest_Inns_Score   Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 2                269*  6187        2667               5568.0    5   4   2
# 6                 194  6073       6558+               3459.0   16  23   2
# 19                122  5500        178+               2921.0    3   6   2
# 25                231  5381        108+               6388.0    9  14   3
# ...

# %% [markdown]
# **Split up Span into start and end date**

# %%
df_matches['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 4     [1963, 1970]
# 5     [1930, 1954]
#           ...
# 64    [1965, 1981]
# 65    [2002, 2014]
# 66    [1924, 1934]
# 67    [1930, 1938]
# 68    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df_matches['Span'].str.split(pat='-').str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 4     1970
# 5     1954
#       ...
# 64    1981
# 65    2014
# 66    1934
# 67    1938
# 68    1934
# Name: Span, Length: 62, dtype: object

# %%
df_matches['Rookie_Year'] = df_matches['Span'].str.split(pat = '-').str[0]

# %%
df_matches['Final_Year'] = df_matches['Span'].str.split(pat = '-').str[1]

# %%
df_matches.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 4   RG Pollock (SA)  1963-1970       23    41         4  2256
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score   Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  9994       9800+               5860.0   29  13  7  626
# 1                186  6215        1287               9176.0    4   7  1  141
# 2               269*  6187        2667               5568.0    5   4  2  186
# 4                274  6097       1707+               5448.0    7  11  1  246
# 5               270*  6083        416+               5600.0   10   5  2  104
#
#    6s Rookie_Year Final_Year
# 0   6        1928       1948
# 1  23        2022       2023
# 2   5        2015       2016
# ...

# %%
df_matches=df_matches.drop(['Span'],axis = 1)

# %%
df_matches.head()
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score   Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  9994
# 1    HC Brook (ENG)       12    20         1  1181                186  6215
# 2    AC Voges (AUS)       20    31         7  1485               269*  6187
# 4   RG Pollock (SA)       23    41         4  2256                274  6097
# 5   GA Headley (WI)       22    40         4  2190               270*  6083
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year
# 0       9800+               5860.0   29  13  7  626   6        1928       1948
# 1        1287               9176.0    4   7  1  141  23        2022       2023
# 2        2667               5568.0    5   4  2  186   5        2015       2016
# 4       1707+               5448.0    7  11  1  246  11        1963       1970
# 5        416+               5600.0   10   5  2  104   1        1930       1954

# %% [markdown]
# **Question: How to split up the country code from the player?**

# %%
df_matches['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 4       [RG Pollock , SA)]
# 5       [GA Headley , WI)]
#               ...
# 64     [KD Walters , AUS)]
# 65    [GC Smith , ICC/SA)]
# 66    [WH Ponsford , AUS)]
# 67      [SJ McCabe , AUS)]
# 68     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df_matches['Country'] = df_matches['Player'].str.split(pat='(').str[1]

# %%
df_matches['Country'] = df_matches['Country'].str.split(pat=')').str[0]

# %%
df_matches['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 4         SA
# 5         WI
#        ...
# 64       AUS
# 65    ICC/SA
# 66       AUS
# 67       AUS
# 68       ENG
# Name: Country, Length: 62, dtype: object

# %%
df_matches['Player'] = df_matches['Player'].str.split(pat='(').str[0]

# %%
df_matches.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score   Ave  \
# 0  DG Bradman        52    80        10  6996                334  9994
# 1    HC Brook        12    20         1  1181                186  6215
# 2    AC Voges        20    31         7  1485               269*  6187
# 4  RG Pollock        23    41         4  2256                274  6097
# 5  GA Headley        22    40         4  2190               270*  6083
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0       9800+               5860.0   29  13  7  626   6        1928
# 1        1287               9176.0    4   7  1  141  23        2022
# 2        2667               5568.0    5   4  2  186   5        2015
# 4       1707+               5448.0    7  11  1  246  11        1963
# 5        416+               5600.0   10   5  2  104   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2023     ENG
# 2       2016     AUS
# 4       1970      SA
# ...

# %% [markdown]
# **Changing Datatypes**

# %%
df_matches.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                      int64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df_matches['Highest_Inns_Score'].str.split(pat='*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 4     274
# 5     270
#      ...
# 64    250
# 65    277
# 66    266
# 67    232
# 68    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df_matches['Highest_Inns_Score']= df_matches['Highest_Inns_Score'].str.split(pat='*').str[0]

# %%
df_matches['Highest_Inns_Score']
# Out:
# 0     334
# 1     186
# 2     269
# 4     274
# 5     270
#      ...
# 64    250
# 65    277
# 66    266
# 67    232
# 68    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %% [markdown]
# Change datatype of Highest inns score: from object to int

# %%
df_matches['Highest_Inns_Score'] = df_matches['Highest_Inns_Score'].astype('int')

# %%
df_matches.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                      int64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %% [markdown]
# Fixing Rookie Year and Final Year

# %%
df_matches = df_matches.astype({'Rookie_Year':'int','Final_Year':'int'})

# %%
df_matches.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                      int64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df_matches.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score   Ave  \
# 0  DG Bradman        52    80        10  6996                 334  9994
# 1    HC Brook        12    20         1  1181                 186  6215
# 2    AC Voges        20    31         7  1485                 269  6187
# 4  RG Pollock        23    41         4  2256                 274  6097
# 5  GA Headley        22    40         4  2190                 270  6083
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0       9800+               5860.0   29  13  7  626   6         1928
# 1        1287               9176.0    4   7  1  141  23         2022
# 2        2667               5568.0    5   4  2  186   5         2015
# 4       1707+               5448.0    7  11  1  246  11         1963
# 5        416+               5600.0   10   5  2  104   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2023     ENG
# 2        2016     AUS
# 4        1970      SA
# ...

# %%
df_matches.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                      int64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df_matches['Balls_Faced']= df_matches['Balls_Faced'].str.split(pat='+').str[0]

# %%
pd.set_option('display.max_rows', None)

# %%
df_matches
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 4         RG Pollock        23    41         4   2256                 274
# 5         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 8          E Paynter        20    31         5   1540                 243
# 9      KF Barrington        82   131        15   6806                 256
# 10         ED Weekes        48    81         5   4455                 207
# 11        WR Hammond        85   140        16   7249                 336
# 12         GS Sobers        93   160        21   8032                 365
# 13     KC Sangakkara       134   233        17  12400                 319
# ...

# %%
df_matches=df_matches.drop(61,axis=0)

# %%
df_matches=df_matches.drop(10,axis=0)

# %%
df_matches
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 4         RG Pollock        23    41         4   2256                 274
# 5         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 8          E Paynter        20    31         5   1540                 243
# 9      KF Barrington        82   131        15   6806                 256
# 11        WR Hammond        85   140        16   7249                 336
# 12         GS Sobers        93   160        21   8032                 365
# 13     KC Sangakkara       134   233        17  12400                 319
# 14         SPD Smith       109   195        25   9685                 239
# ...

# %%
df_matches.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df_matches.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                      int64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df_matches['Balls_Faced'] = df_matches['Balls_Faced'].astype('int')

# %%
df_matches.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                      int64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %% [markdown]
# Question: Build out Career_lenght column

# %%
df_matches['career_lenght'] = df_matches['Final_Year'] - df_matches['Rookie_Year']

# %%
df_matches
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 4         RG Pollock        23    41         4   2256                 274
# 5         GA Headley        22    40         4   2190                 270
# 6        H Sutcliffe        54    84         9   4555                 194
# 8          E Paynter        20    31         5   1540                 243
# 9      KF Barrington        82   131        15   6806                 256
# 11        WR Hammond        85   140        16   7249                 336
# 12         GS Sobers        93   160        21   8032                 365
# 13     KC Sangakkara       134   233        17  12400                 319
# 14         SPD Smith       109   195        25   9685                 239
# ...

# %% [markdown]
# **Avarage career length**

# %%
df_matches['career_lenght'].mean()
# Out:
# 13.288135593220339

# %% [markdown]
# **Avarage Batting_Strike_Rate for cricketers who played over 10 years**

# %%
df_matches[df_matches['career_lenght']> 10]['Batting_Strike_Rate']
# Out:
# 0     5860.0
# 5     5600.0
# 6     3459.0
# 9     4242.0
# 11    3807.0
# 12    5358.0
# 13    5419.0
# 14    5350.0
# 15    4622.0
# 17    3934.0
# 18    4597.0
# 21    5141.0
# 24    5153.0
# 25    6388.0
# 27    5404.0
# 28    6051.0
# 29    4599.0
# 30    4251.0
# 32    5239.0
# 33    5212.0
# 34    5872.0
# 38    4331.0
# 39    4335.0
# 40    4864.0
# 42    6010.0
# 43    5451.0
# 44    4109.0
# 46    6977.0
# 47    3881.0
# 48    5145.0
# 49    5652.0
# 50    5402.0
# 52    4016.0
# 53    3004.0
# 54    8223.0
# 56    5556.0
# 57    5592.0
# 59    2911.0
# 62    4692.0
# 63    4374.0
# 64    4916.0
# 65    5967.0
# Name: Batting_Strike_Rate, dtype: float64

# %% [markdown]
# **Question: Find number of cricketers who played before 1960**

# %%
df_matches[df_matches['Rookie_Year']<1960]['Player'].count()
# Out:
# 20

# %% [markdown]
# **Question: Max Highest Inns Score by country**

# %%
df_matches.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int32

# %%
df_matches.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry', ascending = False)
# Out:
#     Country  Highinncountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 6       IND             254
# 7        NZ             251
# 12      ZIM             232

# %% [markdown]
# **Question: 5 Hundreds, Fifties, ducks(0) AVG by Country**

# %%
df_matches.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      13.000000  22.083333   4.416667
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       17.166667  28.666667   8.500000
# ZIM      12.000000  27.000000   5.000000
